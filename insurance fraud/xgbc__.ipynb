# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, recall_score, make_scorer

# %%
recall_pos = make_scorer(recall_score, pos_label=1)

# %%
import pickle
import pandas as pd

with open('TrainData/train_label_encoded.pkl', 'rb') as f:
    train = pickle.load(f)

train.head()
# Out:
#    DateOfIncident  TypeOfIncident  TypeOfCollission  SeverityOfIncident  \
# 0        0.217735               0                 2                   2
# 1        0.158341               0                 2                   2
# 2       -0.910754               2                 2                   1
# 3       -0.673178               2                 2                   1
# 4       -1.267120               2                 1                   1
#
#    AuthoritiesContacted  IncidentState  IncidentCity  IncidentAddress  \
# 0                     4              4             0              279
# 1                     4              4             4              279
# 2                     3              5             5              980
# 3                     3              6             5              980
# 4                     1              5             5              624
#
#    IncidentTime  NumberOfVehicles  ...  CapitalGains  CapitalLoss  \
# 0      0.851958                 2  ...      1.216956    -0.844038
# 1     -0.287094                 2  ...      1.719899    -0.844038
# 2      1.665567                 0  ...      1.567931    -1.388592
# 3      1.665567                 0  ...      0.898547    -1.736104
# 4     -0.287094                 0  ...     -0.834616    -0.593256
#
#    VehicleMake  VehicleModel  VehicleYOM  PolicyCombinedLimit  \
# 0            1             5    0.547253            -1.081375
# 1            1             5    0.170856            -1.081375
# 2           13            20   -1.147564             1.397586
# 3           13            20   -0.394255             1.397586
# 4           12             8    0.924165            -1.081375
#
#    PolicySingleLimit  ReportedFraud  VehicleAge  PolicyAge
# 0          -0.983964              0   -0.547450   0.533940
# 1          -0.983964              0   -0.170793   0.229272
# 2           1.444450              0    1.147508   0.076938
# 3           1.444450              0    0.394193  -0.532398
# 4          -0.983964              0   -0.924108   0.838608
#
# [5 rows x 40 columns]

# %%
X = train.drop(['ReportedFraud'], axis=1)
y = train['ReportedFraud']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
xgbc = xgb.XGBClassifier()
xgbc.fit(X_train, y_train)

y_pred = xgbc.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.97      0.95      4192
#            1       0.91      0.79      0.84      1576
#
#     accuracy                           0.92      5768
#    macro avg       0.92      0.88      0.90      5768
# weighted avg       0.92      0.92      0.92      5768

# %%
from sklearn.model_selection import RandomizedSearchCV

params = {
    'learning_rate': [0.01, 0.05, 0.1, 0.2, 0.5, 1, 2],
    'max_depth': [3, 5, 7, 9, 11, 13, 15],
    'n_estimators': [10, 50, 100, 200, 500, 1000],
    'subsample': [0.5, 0.6, 0.7, 0.8, 0.9, 1],
    'colsample_bytree': [0.5, 0.6, 0.7, 0.8, 0.9, 1],
    'gamma': [0, 0.25, 0.5, 1],
    'reg_alpha': [0, 0.25, 0.5, 1],
    'reg_lambda': [0, 0.25, 0.5, 1]
}

xgbc = xgb.XGBClassifier(objective='binary:hinge', n_jobs=2, verbosity=1)
random_search = RandomizedSearchCV(xgbc, param_distributions=params, n_iter=100, scoring=recall_pos, n_jobs=2, cv=5, verbose=3)
random_search.fit(X_train, y_train)

res = pd.DataFrame(random_search.cv_results_)

# %%
res = res.sort_values(by='rank_test_score', ascending=True)

import time
with open(f'cvresults/xgboost_[{time.strftime("%Y-%m-%d_%H-%M-%S")}].csv', 'w') as f:
    res.to_csv(f)

res[:10]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.181931      0.008386         0.012995        0.000691
# 72       0.427535      0.045399         0.012401        0.000489
# 36       0.630852      0.003927         0.013202        0.000749
# 49       1.017124      0.009318         0.014203        0.001167
# 27       0.616088      0.030810         0.012602        0.000490
# 65       0.547461      0.008152         0.012601        0.001200
# 43       3.308178      0.039828         0.021816        0.000929
# 73       0.590535      0.004183         0.013403        0.000490
# 85       0.264541      0.028342         0.011002        0.000632
# 70       7.034569      0.077653         0.036007        0.000634
#
#    param_subsample param_reg_lambda param_reg_alpha param_n_estimators  \
# 0                1             0.25             0.5                 10
# 72             0.7              0.5               1                 10
# 36             0.7             0.25               0                 10
# 49             0.5             0.25               1                 50
# 27             0.5                0               0                 10
# 65             0.8                0               0                 10
# 43               1              0.5             0.5                 50
# 73             0.7             0.25            0.25                 10
# 85             0.6              0.5               1                 10
# 70             0.5             0.25               1                100
#
#    param_max_depth param_learning_rate  ... param_colsample_bytree  \
# 0                3                0.05  ...                    0.7
# 72               9                0.01  ...                    0.7
# 36              15                0.05  ...                    0.6
# 49               7                0.01  ...                    0.5
# 27              11                0.01  ...                    0.9
# 65              11                0.05  ...                    0.8
# 43              13                0.01  ...                    0.9
# 73              13                 0.1  ...                    0.7
# 85               7                 0.1  ...                    0.5
# 70              15                0.01  ...                    0.9
#
#                                                params split0_test_score  \
# 0   {'subsample': 1, 'reg_lambda': 0.25, 'reg_alph...          1.000000
# 72  {'subsample': 0.7, 'reg_lambda': 0.5, 'reg_alp...          1.000000
# 36  {'subsample': 0.7, 'reg_lambda': 0.25, 'reg_al...          1.000000
# 49  {'subsample': 0.5, 'reg_lambda': 0.25, 'reg_al...          1.000000
# 27  {'subsample': 0.5, 'reg_lambda': 0, 'reg_alpha...          1.000000
# 65  {'subsample': 0.8, 'reg_lambda': 0, 'reg_alpha...          1.000000
# 43  {'subsample': 1, 'reg_lambda': 0.5, 'reg_alpha...          1.000000
# 73  {'subsample': 0.7, 'reg_lambda': 0.25, 'reg_al...          0.847826
# 85  {'subsample': 0.6, 'reg_lambda': 0.5, 'reg_alp...          0.830918
# 70  {'subsample': 0.5, 'reg_lambda': 0.25, 'reg_al...          0.817230
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            1.000000           1.000000           1.000000
# 72           1.000000           1.000000           1.000000
# 36           1.000000           1.000000           1.000000
# 49           1.000000           1.000000           1.000000
# 27           1.000000           1.000000           1.000000
# 65           1.000000           1.000000           1.000000
# 43           1.000000           1.000000           1.000000
# 73           0.838969           0.851852           0.834811
# 85           0.817230           0.826087           0.833199
# 70           0.806763           0.822061           0.826753
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            1.000000         1.000000        0.000000                1
# 72           1.000000         1.000000        0.000000                1
# 36           1.000000         1.000000        0.000000                1
# 49           1.000000         1.000000        0.000000                1
# 27           1.000000         1.000000        0.000000                1
# 65           1.000000         1.000000        0.000000                1
# 43           1.000000         1.000000        0.000000                1
# 73           0.849436         0.844579        0.006541                8
# 85           0.844605         0.830408        0.008966                9
# 70           0.825282         0.819618        0.007210               10
#
# [10 rows x 21 columns]

# %%
with open('cvresults/xgboost_[2022-12-24_10-10-35].csv', 'rb') as f:
    res = pd.read_csv(f)

res.loc[73, 'params']
# Out:
# "{'subsample': 0.8, 'reg_lambda': 1, 'reg_alpha': 1, 'n_estimators': 100, 'max_depth': 5, 'learning_rate': 2, 'gamma': 0, 'colsample_bytree': 0.6}"

# %%
xgbc = xgb.XGBClassifier(objective='binary:hinge', n_jobs=2, verbosity=1)

params = {
    'learning_rate': [0.1, 0.5, 1, 2, 3],
    'max_depth': [3, 5, 10],
    'n_estimators': [50, 100, 200, 500],
    'subsample': [0.5, 0.8, 1],
    'colsample_bytree': [0.5, 0.6, 0.7, 1],
    'gamma': [0, 0.1, 0.5, 1],
    'reg_alpha': [0, 0.1, 0.5, 1],
    'reg_lambda': [0, 0.1, 0.5, 1]
}


random_search = RandomizedSearchCV(xgbc, param_distributions=params, n_iter=500, scoring=recall_pos, n_jobs=1, cv=5, verbose=1)
random_search.fit(X_train, y_train)

res_2 = pd.DataFrame(random_search.cv_results_)
res_2 = res_2.sort_values(by='rank_test_score', ascending=True)

with open(f'cvresults/xgboost_[{time.strftime("%Y-%m-%d_%H-%M-%S")}].csv', 'w') as f:
    res_2.to_csv(f)
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits

# %%
res_2[:10]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 40      11.216975      1.010250         0.035064    4.161120e-03
# 6        2.208467      0.065796         0.020204    3.994466e-04
# 2        4.144985      0.083466         0.022105    6.665201e-04
# 0        3.886766      0.612589         0.021284    2.259723e-03
# 54       3.734567      0.087769         0.022403    1.357206e-03
# 25       1.841413      0.006767         0.017803    7.524364e-04
# 47       1.686083      0.025986         0.015201    4.015837e-04
# 59       1.470115      0.025446         0.015439    8.144949e-04
# 26       5.524935      0.024834         0.039437    1.300901e-03
# 73       1.520420      0.014255         0.015003    6.975526e-07
#
#    param_subsample param_reg_lambda param_reg_alpha param_n_estimators  \
# 40               1              0.5             0.1                500
# 6                1              0.1             0.1                200
# 2              0.8              0.5             0.1                500
# 0              0.8              0.1               0                100
# 54             0.8              0.5             0.5                500
# 25             0.5              0.1               0                 50
# 47             0.8              0.1               1                200
# 59               1              0.5               0                100
# 26             0.5                1             0.5                200
# 73             0.8                1               1                200
#
#    param_max_depth param_learning_rate  ... param_colsample_bytree  \
# 40              10                   3  ...                      1
# 6                5                 0.1  ...                    0.5
# 2                3                 0.5  ...                    0.6
# 0               10                   3  ...                      1
# 54               3                 0.5  ...                    0.5
# 25              10                 0.1  ...                    0.7
# 47               3                 0.5  ...                    0.6
# 59               5                 0.5  ...                    0.7
# 26              10                 0.1  ...                    0.5
# 73               3                   1  ...                    0.5
#
#                                                params split0_test_score  \
# 40  {'subsample': 1, 'reg_lambda': 0.5, 'reg_alpha...          0.767987
# 6   {'subsample': 1, 'reg_lambda': 0.1, 'reg_alpha...          0.794665
# 2   {'subsample': 0.8, 'reg_lambda': 0.5, 'reg_alp...          0.785772
# 0   {'subsample': 0.8, 'reg_lambda': 0.1, 'reg_alp...          0.787389
# 54  {'subsample': 0.8, 'reg_lambda': 0.5, 'reg_alp...          0.783347
# 25  {'subsample': 0.5, 'reg_lambda': 0.1, 'reg_alp...          0.785772
# 47  {'subsample': 0.8, 'reg_lambda': 0.1, 'reg_alp...          0.784155
# 59  {'subsample': 1, 'reg_lambda': 0.5, 'reg_alpha...          0.784155
# 26  {'subsample': 0.5, 'reg_lambda': 1, 'reg_alpha...          0.765562
# 73  {'subsample': 0.8, 'reg_lambda': 1, 'reg_alpha...          0.770412
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 40           0.850445           0.759095           0.791431
# 6            0.763945           0.796281           0.784155
# 2            0.765562           0.789814           0.772838
# 0            0.808407           0.707357           0.800323
# 54           0.757478           0.792239           0.779305
# 25           0.759903           0.791431           0.764753
# 47           0.762328           0.778496           0.759903
# 59           0.759095           0.767179           0.755861
# 26           0.750202           0.785772           0.765562
# 73           0.743735           0.773646           0.758286
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 40           0.784964         0.790784        0.031993                1
# 6            0.775263         0.782862        0.012138                2
# 2            0.784964         0.779790        0.009097                3
# 0            0.793856         0.779466        0.036721                4
# 54           0.783347         0.779143        0.011630                5
# 25           0.766370         0.773646        0.012524                6
# 47           0.775263         0.772029        0.009386                7
# 59           0.782538         0.769766        0.011697                8
# 26           0.776071         0.768634        0.011897                9
# 73           0.778496         0.764915        0.012518               10
#
# [10 rows x 21 columns]

# %%
params = {
    'learning_rate': [0.01, 0.1, 0.5, 1, 3],
    'max_depth': [3, 5, 10],
    'n_estimators': [300, 500, 1000],
    'subsample': [0.5, 0.8, 1],
    'colsample_bytree': [0.5, 0.8, 1],
    'gamma': [0, 0.1, 0.5, 1],
    'reg_alpha': [0, 0.1, 0.5, 1],
    'reg_lambda': [0, 0.1, 0.5, 1]
}

random_search = RandomizedSearchCV(xgbc, param_distributions=params, n_iter=300, scoring=recall_pos, n_jobs=1, cv=5, verbose=1)
random_search.fit(X_train, y_train)

res_3 = pd.DataFrame(random_search.cv_results_)
res_3 = res_3.sort_values(by='rank_test_score', ascending=True)

with open(f'cvresults/xgboost_[{time.strftime("%Y-%m-%d_%H-%M-%S")}].csv', 'w') as f:
    res_3.to_csv(f)

res_3[:10]
# Out:
# Fitting 5 folds for each of 300 candidates, totalling 1500 fits
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 276      28.069853      0.181791         0.197896        0.026588
# 32       14.749728      0.156022         0.101738        0.004353
# 123      13.190552      0.155334         0.103247        0.000453
# 181      13.731995      0.139567         0.107817        0.002643
# 264      28.438637      0.409585         0.185385        0.003455
# 53       14.205306      0.105069         0.104434        0.016835
# 186       8.549326      1.118822         0.030208        0.002713
# 258      27.345219      0.194613         0.176561        0.001677
# 64       28.815594      0.136801         0.195665        0.000858
# 173      13.238974      0.322552         0.103695        0.003153
#
#     param_subsample param_reg_lambda param_reg_alpha param_n_estimators  \
# 276             0.5                1             0.1               1000
# 32              0.5              0.5               1                500
# 123               1              0.5             0.1                500
# 181               1              0.1               1                500
# 264             0.5                1               0               1000
# 53              0.5              0.5             0.1                500
# 186               1                0               1                300
# 258             0.5                0               0               1000
# 64              0.8                1               1               1000
# 173               1                0               0                500
#
#     param_max_depth param_learning_rate  ... param_colsample_bytree  \
# 276              10                0.01  ...                    0.5
# 32               10                0.01  ...                    0.5
# 123              10                0.01  ...                    0.5
# 181              10                0.01  ...                    0.5
# 264              10                0.01  ...                    0.5
# 53               10                0.01  ...                    0.5
# 186              10                   3  ...                      1
# 258              10                0.01  ...                    0.5
# 64               10                0.01  ...                    0.5
# 173              10                0.01  ...                    0.5
#
#                                                 params split0_test_score  \
# 276  {'subsample': 0.5, 'reg_lambda': 1, 'reg_alpha...          0.808252
# 32   {'subsample': 0.5, 'reg_lambda': 0.5, 'reg_alp...          0.804207
# 123  {'subsample': 1, 'reg_lambda': 0.5, 'reg_alpha...          0.802589
# 181  {'subsample': 1, 'reg_lambda': 0.1, 'reg_alpha...          0.806634
# 264  {'subsample': 0.5, 'reg_lambda': 1, 'reg_alpha...          0.800971
# 53   {'subsample': 0.5, 'reg_lambda': 0.5, 'reg_alp...          0.804207
# 186  {'subsample': 1, 'reg_lambda': 0, 'reg_alpha':...          0.791262
# 258  {'subsample': 0.5, 'reg_lambda': 0, 'reg_alpha...          0.803398
# 64   {'subsample': 0.8, 'reg_lambda': 1, 'reg_alpha...          0.804207
# 173  {'subsample': 1, 'reg_lambda': 0, 'reg_alpha':...          0.800971
#
#      split1_test_score  split2_test_score  split3_test_score  \
# 276           0.787217           0.807443           0.807287
# 32            0.783172           0.803398           0.804858
# 123           0.784790           0.801780           0.809717
# 181           0.781553           0.799353           0.809717
# 264           0.783981           0.800971           0.809717
# 53            0.777508           0.806634           0.801619
# 186           0.804207           0.818770           0.810526
# 258           0.779126           0.805016           0.807287
# 64            0.779935           0.800971           0.808097
# 173           0.783981           0.800162           0.800810
#
#      split4_test_score  mean_test_score  std_test_score  rank_test_score
# 276           0.811489         0.804338        0.008694                1
# 32            0.817152         0.802557        0.010932                2
# 123           0.813107         0.802396        0.009785                3
# 181           0.814725         0.802396        0.011552                3
# 264           0.813107         0.801749        0.010094                5
# 53            0.818770         0.801748        0.013470                6
# 186           0.779935         0.800940        0.013823                7
# 258           0.807443         0.800454        0.010769                8
# 64            0.808252         0.800293        0.010531                9
# 173           0.813916         0.799968        0.009507               10
#
# [10 rows x 21 columns]

# %%
random_search.best_params_
# Out:
# {'subsample': 0.5,
#  'reg_lambda': 1,
#  'reg_alpha': 0.1,
#  'n_estimators': 1000,
#  'max_depth': 10,
#  'learning_rate': 0.01,
#  'gamma': 0,
#  'colsample_bytree': 0.5}

# %%
xgbc = xgb.XGBClassifier(n_jobs=2)

params = {
    'objective': ['binary:hinge', 'binary:logistic'],
    'learning_rate': [0.001, 0.01, 0.05],
    'max_depth': [5, 10, 15],
    'n_estimators': [1000, 1300, 2000],
    'subsample': [0.3, 0.5, 0.7],
    'colsample_bytree': [0.3, 0.5, 0.7],
    'gamma': [0],
    'reg_alpha': [0.1],
    'reg_lambda': [1, 2]
}

from sklearn.model_selection import RandomizedSearchCV
random_search = RandomizedSearchCV(xgbc, param_distributions=params, n_iter=100, scoring=recall_pos, n_jobs=1, cv=5, verbose=1)
random_search.fit(X_train, y_train)

res_4 = pd.DataFrame(random_search.cv_results_)
res_4 = res_4.sort_values(by='rank_test_score', ascending=True)

import time
with open(f'cvresults/xgboost_[{time.strftime("%Y-%m-%d_%H-%M-%S")}].csv', 'w') as f:
    res_4.to_csv(f)

res_4[:10]
